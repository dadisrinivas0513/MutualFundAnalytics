# %% [markdown]
# # Data Ingestion
#
# This notebook documents the data ingestion process for the Mutual Fund Analytics Capstone Project.
#
# ## Objectives
#
# - Load all raw datasets.
# - Verify schema and row counts.
# - Perform initial validation.
# - Prepare data for cleaning.
#
# The automated implementation is available in:
#
# `scripts/etl_pipeline.py`
